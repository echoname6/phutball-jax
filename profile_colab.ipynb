# %% [markdown]
# # Phutball Self-Play Profiler
#
# Runtime → TPU v6e → Run all

# %%
# Install dependencies
# !pip install -q jax[tpu] -f https://storage.googleapis.com/jax-releases/libtpu_releases.html
# !pip install -q flax optax mctx

# %%
# Clone repo
import os
REPO_URL = "https://github.com/echoname6/phutball-jax.git"
REPO_DIR = "/content/phutball-jax"

if os.path.exists(REPO_DIR):
    # !cd {REPO_DIR} && git pull
else:
    # !git clone {REPO_URL} {REPO_DIR}

# %cd {REPO_DIR}
# !git log --oneline -3

# %%
# Run TPU profiler (uses %run to stay in same process)
import sys
sys.argv = ['profile_self_play.py', '--tpu']
# %run profile_self_play.py

# %%
# Run full training config benchmark
import sys
sys.argv = ['profile_self_play.py', '--full']
# %run profile_self_play.py
